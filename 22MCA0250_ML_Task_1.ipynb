# %% [markdown]
# <a href="https://colab.research.google.com/github/vishalkumar437/practice/blob/main/22MCA0250_ML_Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Name: Vishal Kumar Gupta
# ## Reg No: 22MCA0250
# # <center>Multiple Linear Regression</center>
#
# ---

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Importing dataset

# %%
df = pd.read_csv("auto-mpg.csv")

# %% [markdown]
# Splitting and selecting data

# %%
cdf = df[['mpg', 'cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'model year', 'origin', 'car name']]
cdf.drop('car name', axis = 1, inplace = True)
msk = np.random.rand(len(df)) < 0.8
X = cdf[msk]
y = cdf[~msk]

# %% [markdown]
# Visualising Heatmap

# %%
sns.heatmap(X.corr(), annot=True)
# Out:
# <ipython-input-23-53cf1fccd037>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(X.corr(), annot=True)
# <Axes: >

# %% [markdown]
# ## Training MLR

# %%
# Train the Multiple Linear Regression model
from sklearn import linear_model
X_train = np.asanyarray(train[['cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'model year', 'origin']])
y_train = np.asanyarray(train[['mpg']])
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
Error

# %%
X_test = np.asanyarray(test[['cylinders', 'displacement', 'horsepower', 'weight','acceleration', 'model year', 'origin']])
y_test = np.asanyarray(test[['mpg']])
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
rmse = mse**0.5
r_squared = model.score(X_test, y_test)

print("Mean Squared Error (MSE):", mse)
print("Root Mean Squared Error (RMSE):", rmse)
print("R-squared:", r_squared)
# Out:
# Mean Squared Error (MSE): 11.853018740037037
# Root Mean Squared Error (RMSE): 3.4428213343182703
# R-squared: 0.8016944786402782

# %%
# Make predictions on new data
new_data = [[8,4, 200, 100, 3000, 16, 78]]
predicted_mpg = model.predict(new_data)
print("Predicted MPG:", predicted_mpg)
# Out:
# Predicted MPG: [[295.60676335]]
